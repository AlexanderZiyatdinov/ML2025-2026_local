# %% [markdown]
# # Вероятности в ML

# %%
import pandas as pd
import random
from IPython.display import Image

# %% [markdown]
# В этом ноутбуке разговор будет не совсем о ML. Он будет посвящен тем основам, без которых сложно понять и `прочувствовать` саму суть машинного обучения и вероятностного подхода.

# %% [markdown]
# ## Зачем вероятность в ML?

# %% [markdown]
# ## Элементы теории вероятностей

# %% [markdown]
# ## Теорема Байеса
